# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('carprices.csv')

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(df[['Mileage']], df['Sell Price($)'])

# %%
plt.figure(figsize = (8, 4), dpi = 180)
plt.scatter(df['Mileage'], df['Sell Price($)'])
plt.plot(df['Mileage'], reg.predict(df[['Mileage']]), color = 'orange')

# %%
# Setting up X and y dataset
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split
# Selection process is random here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
reg_model = LinearRegression().fit(X_train, y_train)

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 16    28000         2
# 2     57000         5
# 13    58780         4
# 14    82450         7

# %%
y_test
# Out:
# 16    35500
# 2     26100
# 13    27500
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
reg_model.predict(X_test)
# Out:
# array([37086.11375541, 26064.5371606 , 25234.52947812, 16310.12312481])

# %%
reg_model.score(X_train, y_train)
# Out:
# 0.9400171504305371
